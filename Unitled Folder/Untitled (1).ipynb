# %%
import pandas as pd
import numpy as np

# %%
future_df = pd

# %%
future_df
# Out:
#                     time  temperature(°C)  humidity(%)  cloudcover(%)  \
# 0    2024-10-01 00:00:00             18.3           94            100
# 1    2024-10-01 01:00:00             18.4           94             51
# 2    2024-10-01 02:00:00             18.5           93             74
# 3    2024-10-01 03:00:00             18.5           92             84
# 4    2024-10-01 04:00:00             18.2           93            100
# ..                   ...              ...          ...            ...
# 739  2024-10-31 19:00:00             17.6           95              1
# 740  2024-10-31 20:00:00             18.0           93              1
# 741  2024-10-31 21:00:00             18.3           92              1
# 742  2024-10-31 22:00:00             18.1           93              0
# 743  2024-10-31 23:00:00             18.2           92              0
#
#      windspeed(km/h)
# 0               13.8
# 1               14.8
# 2               15.7
# 3               11.1
# ...

# %%
future_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             744 non-null    object
#  1   temperature(°C)  744 non-null    float64
#  2   humidity(%)      744 non-null    int64
#  3   cloudcover(%)    744 non-null    int64
#  4   windspeed(km/h)  744 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 29.2+ KB

# %%
future_df['time'] = pd.to_datetime(future_df['time'])

# %%
future_df['hour'] = future_df['time'].dt.hour
future_df['day'] = future_df['time'].dt.day
future_df['month'] = future_df['time'].dt.month
future_df['year'] = future_df['time'].dt.year

# %%
features = future_df[['hour', 'day', 'month', 'year', 'temperature(°C)', 'humidity(%)', 'cloudcover(%)', 'windspeed(km/h)']]

# %%
future_df
# Out:
#      hour  day  month  year  temperature(°C)  humidity(%)  cloudcover(%)  \
# 0       0    1     10  2024             18.3           94            100
# 1       1    1     10  2024             18.4           94             51
# 2       2    1     10  2024             18.5           93             74
# 3       3    1     10  2024             18.5           92             84
# 4       4    1     10  2024             18.2           93            100
# ..    ...  ...    ...   ...              ...          ...            ...
# 739    19   31     10  2024             17.6           95              1
# 740    20   31     10  2024             18.0           93              1
# 741    21   31     10  2024             18.3           92              1
# 742    22   31     10  2024             18.1           93              0
# 743    23   31     10  2024             18.2           92              0
#
#      windspeed(km/h)
# 0               13.8
# 1               14.8
# 2               15.7
# ...

# %%
# En iyi modeli yükleyin
best_model = joblib.load('GradientBoostingRegressor_Model.joblib')

# Enerji tüketimini tahmin edin
future_df['Predicted_Consumption_kWh'] = best_model.predict(features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 5
#       2 best_model = joblib.load('GradientBoostingRegressor_Model.joblib')
#       4 # Enerji tüketimini tahmin edin
# ----> 5 future_df['Predicted_Consumption_kWh'] = best_model.predict(features)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_gb.py:2125, in GradientBoostingRegressor.predict(self, X)
#    2110 def predict(self, X):
#    2111     """Predict regression target for X.
#    2112
#    2113     Parameters
#    (...)
#    2123         The predicted values.
#    2124     """
# -> 2125     X = self._validate_data(
#    2126         X, dtype=DTYPE, order="C", accept_sparse="csr", reset=False
#    2127     )
#    2128     # In regression we can directly return the raw value from the trees.
#    2129     return self._raw_predict(X).ravel()
#
# ...
