# %%
import pandas as pd

# %%
df = pd.read_csv('weather.csv')

# %%
df
# Out:
#               latitude            longitude                 elevation  \
# 0             41.01933            28.887304                      32.0
# 1                 time  temperature_2m (°C)  relative_humidity_2m (%)
# 2     2023-07-09T00:00                 21.6                        69
# 3     2023-07-09T01:00                 21.4                        66
# 4     2023-07-09T02:00                 21.2                        67
# ...                ...                  ...                       ...
# 8805  2024-07-09T19:00                 28.3                        72
# 8806  2024-07-09T20:00                 26.9                        79
# 8807  2024-07-09T21:00                 25.9                        84
# 8808  2024-07-09T22:00                 25.3                        87
# 8809  2024-07-09T23:00                 25.0                        89
#
#      utc_offset_seconds               timezone  \
# 0                 10800        Europe/Istanbul
# 1       cloud_cover (%)  wind_speed_10m (km/h)
# 2                    21                   20.8
# 3                    30                   22.0
# 4                    33                   22.0
# ...                 ...                    ...
# 8805                  0                   25.2
# 8806                  0                   25.7
# 8807                  0                   24.3
# 8808                  0                   21.9
# 8809                  0                   21.4
#
#                 timezone_abbreviation
# 0                                 +03
# 1     direct_radiation_instant (W/m²)
# 2                                 0.0
# 3                                 0.0
# 4                                 0.0
# ...                               ...
# 8805                            154.0
# 8806                             33.6
# 8807                              0.0
# 8808                              0.0
# 8809                              0.0
#
# [8810 rows x 6 columns]

# %%
df.columns = ['time', 'temperature(°C)', 'humidity(%)', 'cloudcover(%)', 'windspeed(km/h)', 'irrediance(W/m²)' ]

# %%
df
# Out:
#                   time      temperature(°C)               humidity(%)  \
# 0             41.01933            28.887304                      32.0
# 1                 time  temperature_2m (°C)  relative_humidity_2m (%)
# 2     2023-07-09T00:00                 21.6                        69
# 3     2023-07-09T01:00                 21.4                        66
# 4     2023-07-09T02:00                 21.2                        67
# ...                ...                  ...                       ...
# 8805  2024-07-09T19:00                 28.3                        72
# 8806  2024-07-09T20:00                 26.9                        79
# 8807  2024-07-09T21:00                 25.9                        84
# 8808  2024-07-09T22:00                 25.3                        87
# 8809  2024-07-09T23:00                 25.0                        89
#
#         cloudcover(%)        windspeed(km/h)                 irrediance(W/m²)
# 0               10800        Europe/Istanbul                              +03
# 1     cloud_cover (%)  wind_speed_10m (km/h)  direct_radiation_instant (W/m²)
# 2                  21                   20.8                              0.0
# 3                  30                   22.0                              0.0
# 4                  33                   22.0                              0.0
# ...               ...                    ...                              ...
# 8805                0                   25.2                            154.0
# 8806                0                   25.7                             33.6
# 8807                0                   24.3                              0.0
# 8808                0                   21.9                              0.0
# 8809                0                   21.4                              0.0
#
# [8810 rows x 6 columns]

# %%
df = df.iloc[2:]

# %%
df
# Out:
#                   time temperature(°C) humidity(%) cloudcover(%)  \
# 2     2023-07-09T00:00            21.6          69            21
# 3     2023-07-09T01:00            21.4          66            30
# 4     2023-07-09T02:00            21.2          67            33
# 5     2023-07-09T03:00            20.4          62            49
# 6     2023-07-09T04:00            20.3          62           100
# ...                ...             ...         ...           ...
# 8805  2024-07-09T19:00            28.3          72             0
# 8806  2024-07-09T20:00            26.9          79             0
# 8807  2024-07-09T21:00            25.9          84             0
# 8808  2024-07-09T22:00            25.3          87             0
# 8809  2024-07-09T23:00            25.0          89             0
#
#      windspeed(km/h) irrediance(W/m²)
# 2               20.8              0.0
# 3               22.0              0.0
# 4               22.0              0.0
# 5               21.9              0.0
# 6               19.7              0.0
# ...              ...              ...
# 8805            25.2            154.0
# 8806            25.7             33.6
# 8807            24.3              0.0
# 8808            21.9              0.0
# 8809            21.4              0.0
#
# [8808 rows x 6 columns]

# %%
df.to_csv('weather2.csv')
